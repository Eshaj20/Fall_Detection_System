# %%
# !git clone https://github.com/nhoyh/HR_IMU_falldetection_dataset.git
# !cd HR_IMU_falldetection_dataset
# Out:
# Cloning into 'HR_IMU_falldetection_dataset'...
# remote: Enumerating objects: 460, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 460 (delta 28), reused 45 (delta 28), pack-reused 415 (from 1)
# Receiving objects: 100% (460/460), 12.30 MiB | 22.07 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
# !pip install scipy pandas numpy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import scipy.io

# Load a sample .mat file
mat = scipy.io.loadmat("/content/HR_IMU_falldetection_dataset/subject_01/fall/fall1.mat")

# Check the structure of the file
print(mat.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'time', 'w', 'x', 'y', 'z', 'droll', 'dpitch', 'dyaw', 'ax', 'ay', 'az', 'heart'])

# %%
# prompt: convert all .mat files in the dataset with structure HR_IMU_falldetection_dataset/subject_num/fall_or_nonfall/file.mat into csv files.
# save this new csv dataset.
# now take all the entries from the csv dataset, and combine them into one dataset. all data points have the same features.

import scipy.io
import pandas as pd
import os
import numpy as np

# Define the path to the dataset
dataset_path = "/content/HR_IMU_falldetection_dataset"

# Create a list to store all dataframes
all_dataframes = []

# Iterate through all subjects, fall/non-fall directories, and .mat files
for subject in os.listdir(dataset_path):
    # Skip hidden files or directories like .gitattributes and other files
    if subject.startswith('.') or not os.path.isdir(os.path.join(dataset_path, subject)):
        continue

    subject_dir = os.path.join(dataset_path, subject)
    if not os.path.isdir(subject_dir):
      continue

    for fall_type in ["fall", "non-fall"]:
        fall_dir = os.path.join(subject_dir, fall_type)
        for filename in os.listdir(fall_dir):
            if filename.endswith(".mat"):
                mat_file_path = os.path.join(fall_dir, filename)

                # Load the .mat file
                try:
                    mat = scipy.io.loadmat(mat_file_path)
                    # Get the minimum length among all arrays
                    min_len = min(len(mat[key].flatten()) for key in ["time", "w", "x", "y", "z", "droll", "dpitch", "dyaw", "ax", "ay", "az", "heart"] if key in mat)

                    # Extract data into a dictionary with consistent lengths
                    data_dict = {
                        # "time": mat["time"].flatten()[:min_len],
                        "w": mat["w"].flatten()[:min_len],
                        "x": mat["x"].flatten()[:min_len],
                        "y": mat["y"].flatten()[:min_len],
                        "z": mat["z"].flatten()[:min_len],
                        "droll": mat["droll"].flatten()[:min_len],
                        "dpitch": mat["dpitch"].flatten()[:min_len],
                        "dyaw": mat["dyaw"].flatten()[:min_len],
                        "ax": mat["ax"].flatten()[:min_len],
                        "ay": mat["ay"].flatten()[:min_len],
                        "az": mat["az"].flatten()[:min_len],
                        # "heart": mat["heart"].flatten()[:min_len]
                    }
                    data_dict['label'] = fall_type
                    # Convert to DataFrame
                    all_dataframes.append(pd.DataFrame(data_dict))
                    print(f"Processed {mat_file_path}")
                except Exception as e:
                    print(f"Error processing {mat_file_path}: {e}")

# Concatenate all dataframes into one
if all_dataframes:
    combined_df = pd.concat(all_dataframes, ignore_index=True)

    # Save combined dataset as a CSV file
    combined_df.to_csv("/content/combined_dataset.csv", index=False)
    print("Combined dataset saved as combined_dataset.csv")
else:
    print("No .mat files found or processed.")
# Out:
# Processed /content/HR_IMU_falldetection_dataset/subject_21/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_21/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_07/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_06/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_20/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_02/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_14/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_03/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_10/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_05/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_16/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_04/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_01/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_18/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_15/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_17/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/fall/fall4.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_19/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_09/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_12/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_08/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/write.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/hair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_11/non-fall/bed.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/fall/fall3.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/fall/fall1.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/fall/fall2.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/fall/fall6.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/fall/fall5.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/eat.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/clap.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/teeth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/chair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/stair.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/zip.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/cloth.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/walk.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/shoe.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/wash.mat
# Processed /content/HR_IMU_falldetection_dataset/subject_13/non-fall/bed.mat
# Combined dataset saved as combined_dataset.csv

# %%
df = pd.read_csv("/content/combined_dataset.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381394 entries, 0 to 381393
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   w       381394 non-null  float64
#  1   x       381394 non-null  float64
#  2   y       381394 non-null  float64
#  3   z       381394 non-null  float64
#  4   droll   381394 non-null  float64
#  5   dpitch  381394 non-null  float64
#  6   dyaw    381394 non-null  float64
#  7   ax      381394 non-null  float64
#  8   ay      381394 non-null  float64
#  9   az      381394 non-null  float64
#  10  label   381394 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 32.0+ MB

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

scaler = StandardScaler()
# x = df.drop(['label'], axis=1)
df_fall = df[df['label'] == 'fall']
df_non = df[df['label'] == 'non-fall']
df_non = shuffle(df_non, random_state=42).reset_index(drop=True)
df_non = df_non.iloc[:len(df_fall)]
dataset = df.copy()
df = pd.concat([df_fall, df_non])
x = df.drop(['label'], axis=1)
y = df['label']

# %%
# prompt: use matplotlib to create a bar graph with distribution of labels

import matplotlib.pyplot as plt

# Assuming 'dataset' DataFrame is already loaded as in the previous code

# Count the occurrences of each label
label_counts = df['label'].value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
plt.bar(label_counts.index, label_counts.values)
plt.xlabel("Labels")
plt.ylabel("Frequency")
plt.title("Distribution of Labels")
plt.xticks(rotation=90)  # Rotate x-axis labels for readability if needed
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
x.head(), x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 178720 entries, 0 to 89359
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   w       178720 non-null  float64
#  1   x       178720 non-null  float64
#  2   y       178720 non-null  float64
#  3   z       178720 non-null  float64
#  4   droll   178720 non-null  float64
#  5   dpitch  178720 non-null  float64
#  6   dyaw    178720 non-null  float64
#  7   ax      178720 non-null  float64
#  8   ay      178720 non-null  float64
#  9   az      178720 non-null  float64
# dtypes: float64(10)
# memory usage: 15.0 MB
# (        w       x       y       z  droll  dpitch  dyaw     ax     ay     az
#  0  0.1288  0.4937  0.0966  0.8545    0.0     0.0   0.0  0.002 -0.012  0.000
#  1  0.1285  0.4937  0.0967  0.8545    1.4     0.3  -0.2  0.005 -0.006  0.000
#  2  0.1282  0.4938  0.0969  0.8545    1.3     0.0  -0.3  0.009  0.003 -0.006
#  3  0.1280  0.4938  0.0971  0.8545    0.5     0.0  -0.3  0.013  0.009 -0.008
#  4  0.1281  0.4938  0.0974  0.8545    0.0     0.0   0.0  0.009  0.009 -0.011,
#  None)

# %%
import scipy.io
import pandas as pd

# Load the .mat file
mat = scipy.io.loadmat('/content/HR_IMU_falldetection_dataset/subject_02/non-fall/chair.mat')

# Extract the desired features
features = ['w', 'x', 'y', 'z', 'droll', 'dpitch', 'dyaw', 'ax', 'ay', 'az']
data = {feature: mat[feature].flatten() for feature in features if feature in mat}

# Create a pandas DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#            w       x       y       z  droll  dpitch  dyaw     ax     ay     az
# 0     0.7944 -0.1699 -0.5801 -0.0593 -218.7     1.8   7.1 -0.021  0.095 -0.297
# 1     0.7873 -0.1963 -0.5787 -0.0808 -180.3     9.6  15.7  0.058  0.065 -0.278
# 2     0.7797 -0.2158 -0.5792 -0.0994 -137.1    20.3  31.5  0.010  0.063 -0.245
# 3     0.7724 -0.2268 -0.5818 -0.1156  -84.2    21.9  53.3  0.008  0.010 -0.170
# 4     0.7661 -0.2281 -0.5867 -0.1289  -26.2    16.5  78.3 -0.012 -0.012 -0.094
# ...      ...     ...     ...     ...    ...     ...   ...    ...    ...    ...
# 1044  0.6066 -0.4639 -0.5135 -0.3912    1.8   -31.4 -35.0  0.148  0.111  0.000
# 1045  0.6113 -0.4639 -0.5080 -0.3910   -0.6   -31.5 -26.7  0.142  0.088 -0.011
# 1046  0.6154 -0.4632 -0.5031 -0.3917    1.1   -32.7 -16.5  0.134  0.068 -0.029
# 1047  0.6191 -0.4613 -0.4991 -0.3933    5.0   -34.0  -5.2  0.140  0.066 -0.034
# 1048  0.6223 -0.4580 -0.4963 -0.3956    8.4   -34.0   5.6  0.144  0.055 -0.052
#
# [1049 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Training samples: {X_train.shape[0]}, Testing samples: {X_test.shape[0]}")
# Out:
# Training samples: 142976, Testing samples: 35744

# %%
from sklearn.ensemble import RandomForestClassifier

# Train a Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=20, max_samples=X_train.shape[0]//10, min_samples_split=100, verbose=1)
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   14.7s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.1s finished

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")

# Print Classification Report
print(classification_report(y_test, y_pred))

# Print Confusion Matrix
print("Confusion Matrix:")
conf = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred).plot(cmap='Blues')
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Model Accuracy: 0.92
#               precision    recall  f1-score   support
#
#         fall       0.95      0.88      0.91     17756
#     non-fall       0.89      0.96      0.92     17988
#
#     accuracy                           0.92     35744
#    macro avg       0.92      0.92      0.92     35744
# weighted avg       0.92      0.92      0.92     35744
#
# Confusion Matrix:

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Fit the LabelEncoder to your training labels and transform them
y_train_encoded = le.fit_transform(y_train)

# Initialize the XGBoost model
model_xgb = XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=10, use_label_encoder=False, eval_metric='mlogloss')

# Train the model
model_xgb.fit(X_train, y_train_encoded)

# Make predictions
y_pred_xgb = model_xgb.predict(X_test)

# Transform predictions back to original labels if needed
y_pred_decoded = le.inverse_transform(y_pred_xgb)

# Evaluate the model
accuracy_xgb = accuracy_score(y_test, y_pred_decoded)
print(f"XGBoost Accuracy: {accuracy_xgb:.2f}")

print(classification_report(y_test, y_pred_decoded))

print("Confusion Matrix:")
conf_xgb = confusion_matrix(y_test, y_pred_decoded)
ConfusionMatrixDisplay.from_predictions(y_test,y_pred_decoded).plot(cmap='Blues')
plt.title("XGBoost Confusion Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:20:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 0.91
#               precision    recall  f1-score   support
#
#         fall       0.93      0.90      0.91     17756
#     non-fall       0.90      0.93      0.92     17988
#
#     accuracy                           0.91     35744
#    macro avg       0.92      0.91      0.91     35744
# weighted avg       0.92      0.91      0.91     35744
#
# Confusion Matrix:

# %%
# !pip install catboost
from catboost import CatBoostClassifier


model_catboost = CatBoostClassifier(iterations=100, learning_rate=0.01, depth=10, loss_function='MultiClass')

# Train the model
model_catboost.fit(X_train, y_train, verbose=1)

# Make predictions
y_pred_catboost = model_catboost.predict(X_test)

# Evaluate the model
accuracy_catboost = accuracy_score(y_test, y_pred_catboost)
print(f"CatBoost Accuracy: {accuracy_catboost:.2f}")

print(classification_report(y_test, y_pred_catboost))

print("Confusion Matrix:")
conf_catboost = confusion_matrix(y_test, y_pred_catboost)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_catboost).plot(cmap='Blues')
plt.title("CatBoost Confusion Matrix")
plt.show()
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.2 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8
# 0:	learn: 0.6873310	total: 241ms	remaining: 23.8s
# 1:	learn: 0.6817340	total: 425ms	remaining: 20.8s
# 2:	learn: 0.6762863	total: 615ms	remaining: 19.9s
# 3:	learn: 0.6711395	total: 809ms	remaining: 19.4s
# 4:	learn: 0.6656289	total: 995ms	remaining: 18.9s
# 5:	learn: 0.6604472	total: 1.19s	remaining: 18.7s
# 6:	learn: 0.6553643	total: 1.4s	remaining: 18.6s
# 7:	learn: 0.6503762	total: 1.58s	remaining: 18.2s
# 8:	learn: 0.6452603	total: 1.77s	remaining: 17.9s
# 9:	learn: 0.6405288	total: 1.95s	remaining: 17.5s
# 10:	learn: 0.6357038	total: 2.15s	remaining: 17.4s
# 11:	learn: 0.6307859	total: 2.35s	remaining: 17.2s
# 12:	learn: 0.6261101	total: 2.53s	remaining: 16.9s
# 13:	learn: 0.6216129	total: 2.71s	remaining: 16.7s
# 14:	learn: 0.6171630	total: 2.9s	remaining: 16.4s
# 15:	learn: 0.6125968	total: 3.08s	remaining: 16.2s
# 16:	learn: 0.6081584	total: 3.42s	remaining: 16.7s
# 17:	learn: 0.6039395	total: 3.75s	remaining: 17.1s
# 18:	learn: 0.5995531	total: 4.09s	remaining: 17.4s
# 19:	learn: 0.5954093	total: 4.46s	remaining: 17.8s
# 20:	learn: 0.5911789	total: 4.8s	remaining: 18.1s
# 21:	learn: 0.5871726	total: 5.13s	remaining: 18.2s
# 22:	learn: 0.5834788	total: 5.47s	remaining: 18.3s
# 23:	learn: 0.5798711	total: 5.79s	remaining: 18.3s
# 24:	learn: 0.5758028	total: 6.12s	remaining: 18.4s
# 25:	learn: 0.5721170	total: 6.35s	remaining: 18.1s
# 26:	learn: 0.5683251	total: 6.55s	remaining: 17.7s
# 27:	learn: 0.5645420	total: 6.74s	remaining: 17.3s
# 28:	learn: 0.5606975	total: 6.92s	remaining: 16.9s
# 29:	learn: 0.5570363	total: 7.09s	remaining: 16.6s
# 30:	learn: 0.5532751	total: 7.28s	remaining: 16.2s
# 31:	learn: 0.5502949	total: 7.48s	remaining: 15.9s
# 32:	learn: 0.5468257	total: 7.67s	remaining: 15.6s
# 33:	learn: 0.5433013	total: 7.86s	remaining: 15.3s
# 34:	learn: 0.5399166	total: 8.04s	remaining: 14.9s
# 35:	learn: 0.5365448	total: 8.23s	remaining: 14.6s
# 36:	learn: 0.5333230	total: 8.41s	remaining: 14.3s
# 37:	learn: 0.5300293	total: 8.62s	remaining: 14.1s
# 38:	learn: 0.5271216	total: 8.8s	remaining: 13.8s
# 39:	learn: 0.5239260	total: 8.97s	remaining: 13.5s
# 40:	learn: 0.5208458	total: 9.16s	remaining: 13.2s
# 41:	learn: 0.5178412	total: 9.34s	remaining: 12.9s
# 42:	learn: 0.5149312	total: 9.55s	remaining: 12.7s
# 43:	learn: 0.5120557	total: 9.73s	remaining: 12.4s
# 44:	learn: 0.5091757	total: 9.91s	remaining: 12.1s
# 45:	learn: 0.5065698	total: 10.1s	remaining: 11.8s
# 46:	learn: 0.5039608	total: 10.3s	remaining: 11.6s
# 47:	learn: 0.5016128	total: 10.4s	remaining: 11.3s
# 48:	learn: 0.4988949	total: 10.6s	remaining: 11.1s
# 49:	learn: 0.4962539	total: 10.8s	remaining: 10.8s
# 50:	learn: 0.4937410	total: 11s	remaining: 10.6s
# 51:	learn: 0.4910476	total: 11.2s	remaining: 10.3s
# 52:	learn: 0.4884055	total: 11.4s	remaining: 10.1s
# 53:	learn: 0.4858660	total: 11.6s	remaining: 9.85s
# 54:	learn: 0.4834692	total: 11.8s	remaining: 9.64s
# 55:	learn: 0.4811031	total: 11.9s	remaining: 9.39s
# 56:	learn: 0.4785099	total: 12.1s	remaining: 9.15s
# 57:	learn: 0.4764955	total: 12.3s	remaining: 8.9s
# 58:	learn: 0.4742156	total: 12.5s	remaining: 8.69s
# 59:	learn: 0.4720123	total: 12.7s	remaining: 8.47s
# 60:	learn: 0.4695797	total: 12.9s	remaining: 8.24s
# 61:	learn: 0.4674368	total: 13.1s	remaining: 8.01s
# 62:	learn: 0.4653741	total: 13.3s	remaining: 7.78s
# 63:	learn: 0.4634299	total: 13.4s	remaining: 7.55s
# 64:	learn: 0.4615596	total: 13.6s	remaining: 7.32s
# 65:	learn: 0.4594231	total: 13.8s	remaining: 7.11s
# 66:	learn: 0.4576038	total: 14s	remaining: 6.88s
# 67:	learn: 0.4555534	total: 14.2s	remaining: 6.67s
# 68:	learn: 0.4534371	total: 14.4s	remaining: 6.45s
# 69:	learn: 0.4512178	total: 14.6s	remaining: 6.24s
# 70:	learn: 0.4491292	total: 14.8s	remaining: 6.03s
# 71:	learn: 0.4471380	total: 15s	remaining: 5.82s
# 72:	learn: 0.4452929	total: 15.2s	remaining: 5.61s
# 73:	learn: 0.4432834	total: 15.3s	remaining: 5.39s
# 74:	learn: 0.4412892	total: 15.5s	remaining: 5.17s
# 75:	learn: 0.4394708	total: 15.7s	remaining: 4.96s
# 76:	learn: 0.4378563	total: 15.9s	remaining: 4.75s
# 77:	learn: 0.4359469	total: 16.1s	remaining: 4.54s
# 78:	learn: 0.4342418	total: 16.3s	remaining: 4.33s
# 79:	learn: 0.4327950	total: 16.6s	remaining: 4.14s
# 80:	learn: 0.4313168	total: 16.9s	remaining: 3.96s
# 81:	learn: 0.4297062	total: 17.2s	remaining: 3.78s
# 82:	learn: 0.4281671	total: 17.5s	remaining: 3.59s
# 83:	learn: 0.4265767	total: 17.8s	remaining: 3.4s
# 84:	learn: 0.4251693	total: 18.1s	remaining: 3.2s
# 85:	learn: 0.4231832	total: 18.5s	remaining: 3s
# 86:	learn: 0.4212024	total: 18.8s	remaining: 2.8s
# 87:	learn: 0.4195589	total: 19.1s	remaining: 2.6s
# 88:	learn: 0.4179315	total: 19.3s	remaining: 2.38s
# 89:	learn: 0.4164147	total: 19.4s	remaining: 2.16s
# 90:	learn: 0.4149960	total: 19.6s	remaining: 1.94s
# 91:	learn: 0.4135665	total: 19.8s	remaining: 1.72s
# 92:	learn: 0.4121901	total: 20s	remaining: 1.5s
# 93:	learn: 0.4109343	total: 20.2s	remaining: 1.29s
# 94:	learn: 0.4094149	total: 20.3s	remaining: 1.07s
# 95:	learn: 0.4078664	total: 20.5s	remaining: 855ms
# 96:	learn: 0.4063529	total: 20.7s	remaining: 640ms
# 97:	learn: 0.4046982	total: 20.9s	remaining: 426ms
# 98:	learn: 0.4034768	total: 21.1s	remaining: 213ms
# 99:	learn: 0.4016896	total: 21.3s	remaining: 0us
# CatBoost Accuracy: 0.89
#               precision    recall  f1-score   support
#
#         fall       0.90      0.86      0.88     17756
#     non-fall       0.87      0.91      0.89     17988
#
#     accuracy                           0.89     35744
#    macro avg       0.89      0.89      0.89     35744
# weighted avg       0.89      0.89      0.89     35744
#
# Confusion Matrix:

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the model
model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(X_train_scaled, y_train)

# Make predictions
y_pred_knn = model_knn.predict(X_test_scaled)

# Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print(f"KNN Accuracy: {accuracy_knn:.2f}")

print(classification_report(y_test, y_pred_knn))

print("Confusion Matrix:")
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_knn).plot(cmap='Blues')
plt.title("KNN Confusion Matrix")
plt.show()
# Out:
# KNN Accuracy: 0.98
#               precision    recall  f1-score   support
#
#         fall       0.99      0.97      0.98     17872
#     non-fall       0.97      0.99      0.98     17872
#
#     accuracy                           0.98     35744
#    macro avg       0.98      0.98      0.98     35744
# weighted avg       0.98      0.98      0.98     35744
#
# Confusion Matrix:

# %%
import joblib

# Save Random Forest model
joblib.dump(model, 'random_forest_model.pkl')

# Save XGBoost model
joblib.dump(model_xgb, 'xgboost_model.pkl')

# Save CatBoost model
joblib.dump(model_catboost, 'catboost_model.pkl')

# Save KNN model
joblib.dump(model_knn, 'knn_model.pkl')
# Out:
# ['knn_model.pkl']
